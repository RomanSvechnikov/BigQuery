# %% [markdown]
# <a href="https://colab.research.google.com/github/RomanSvechnikov/BigQuery/blob/main/BigQuery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'arcane-footing-382312' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# Задача: "С помощью открытого набора данных baseball выведи имя и фамилию питчера обладающего самой высокой скоростью броска для каждой команды за все сезоны. В качестве ответа на данный вопрос необходимо предоставить SQL запрос, который выводит необходимые данные, а также сами эти данные, отсортированные по названию команды в порядке возрастания."

# %% [markdown]
# SQL код, который использовался для решения задачи.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_1c27f5df_18949aedd9c') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# SELECT awayTeamName, pitcherFirstName, pitcherLastName, pitchSpeed
# FROM `bigquery-public-data.baseball.games_wide`
# GROUP BY awayTeamName, pitcherFirstName, pitcherLastName, pitchSpeed
# HAVING COUNT(awayTeamName) = MAX(pitchSpeed)
# ORDER BY awayTeamName ASC

# %% [markdown]
# Результат выполненного запроса.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_1c27f5df_18949aedd9c') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
#    awayTeamName pitcherFirstName pitcherLastName  pitchSpeed
# 0        Angels          Jhoulys          Chacin          82
# 1        Astros           Dallas         Keuchel          90
# 2     Cardinals           Carlos        Martinez          84
# 3          Cubs             John          Lackey          83
# 4      Mariners            James          Paxton          98
# 5      Mariners            Felix       Hernandez          79
# 6     Nationals           Joseph            Ross          83
# 7       Orioles           Ubaldo         Jimenez          89
# 8      Phillies            Jerad        Eickhoff          89
# 9       Pirates             Chad            Kuhl          94
# 10         Rays             Todd           Smyly          88
# 11      Red Sox            David           Price          84
# 12        Twins           Carlos         Nolasco          80
# 13      Yankees          Carsten        Sabathia          80

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe()
# Out:
#        pitchSpeed
# count        14.0
# mean    85.928571
# std      5.608569
# min          79.0
# 25%         82.25
# 50%          84.0
# 75%          89.0
# max          98.0

# %% [markdown]
# Ссылка на BigQuery: https://console.cloud.google.com/bigquery?sq=468545478425:ef830032d0ca4a2da0f7e36f34647097
